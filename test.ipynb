# %%
from IPython.display import Image

# %%
# !darknet detector test data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_1000.weights -dont_show -ext_output data/pklot/test/2013-04-15_17_40_12_jpg.rf.a6d4f6f69f8320b5fa04170ecbff8d5a.jpg
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 16 K-images (0 Kilo-batches_64)
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/pklot/test/2013-04-15_17_40_12_jpg.rf.a6d4f6f69f8320b5fa04170ecbff8d5a.jpg: Predicted in 54.009000 milli-seconds.
# space-occupied: 59%	(left_x:  131   top_y:   37   width:   56   height:   51)
# space-occupied: 54%	(left_x:  132   top_y:   67   width:   79   height:   49)
# space-occupied: 46%	(left_x:  148   top_y:   46   width:   34   height:   38)
# space-occupied: 82%	(left_x:  152   top_y:   75   width:   46   height:   36)
# space-occupied: 86%	(left_x:  152   top_y:  102   width:   60   height:   45)
# ...

# %%
Image(filename='predictions.jpg')

# %%
# !darknet detector test data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_final.weights -dont_show -ext_output data/pklot/test/2013-04-15_17_40_12_jpg.rf.a6d4f6f69f8320b5fa04170ecbff8d5a.jpg
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 96 K-images (1 Kilo-batches_64)
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/pklot/test/2013-04-15_17_40_12_jpg.rf.a6d4f6f69f8320b5fa04170ecbff8d5a.jpg: Predicted in 54.434000 milli-seconds.
# space-occupied: 99%	(left_x:  140   top_y:   48   width:   43   height:   39)
# space-occupied: 100%	(left_x:  150   top_y:   73   width:   47   height:   41)
# space-occupied: 100%	(left_x:  159   top_y:  100   width:   49   height:   50)
# space-occupied: 100%	(left_x:  172   top_y:  137   width:   53   height:   47)
# space-occupied: 97%	(left_x:  174   top_y:   28   width:   44   height:   38)
# ...

# %%
Image(filename='predictions.jpg')
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 96 K-images (1 Kilo-batches_64)
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/pklot/test/2012-09-11_15_53_00_jpg.rf.8282544a640a23df05bd245a9210e663.jpg: Predicted in 52.187000 milli-seconds.
# space-occupied: 95%	(left_x:   19   top_y:  442   width:   36   height:   54)
# space-empty: 100%	(left_x:   44   top_y:  441   width:   35   height:   57)
# space-empty: 96%	(left_x:   66   top_y:  365   width:   27   height:   53)
# space-occupied: 99%	(left_x:   70   top_y:  443   width:   35   height:   54)
# space-occupied: 97%	(left_x:   79   top_y:  369   width:   31   height:   52)
# ...
