# %%
import cv2
import matplotlib.pyplot as plt
from IPython.display import Video
# %matplotlib inline

def imShow(path):
    image = cv2.imread(path)
    height, width = image.shape[:2]
    resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)
    fig = plt.gcf()
    fig.set_size_inches(18, 10)
    plt.axis("off")
    plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    plt.show()

def convert_avi_to_mp4(avi_file_path, output_name):
    os.popen("ffmpeg -i '{input}' -ac 2 -b:v 2000k -c:a aac -c:v libx264 -b:a 160k -vprofile high -bf 0 -strict experimental -f mp4 '{output}.mp4'".format(input = avi_file_path, output = output_name))
    return True

# %%
imShow('data/dog.jpg')

# %%
# !darknet detector test cfg/coco.data cfg/yolov4.cfg -dont_show yolov4.weights data/dog.jpg -i 0 -thresh 0.25
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 32032 K-images (500 Kilo-batches_64)
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/dog.jpg: Predicted in 40.114000 milli-seconds.
# bicycle: 92%
# dog: 98%
# truck: 92%
# pottedplant: 33%
#  CUDA-version: 11020 (11060), cuDNN: 8.1.0, GPU count: 1
#  OpenCV version: 4.5.5
#  0 : compute_capability = 860, cudnn_half = 0, GPU: NVIDIA GeForce RTX 3060
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
# ...

# %%
imShow('predictions.jpg')

# %%
# !darknet detector demo cfg/coco.data cfg/yolov4.cfg yolov4.weights -dont_show data/avengers.mkv -i 0 -ext_output test.mp4
# Out:
# Demo
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 32032 K-images (500 Kilo-batches_64)
# video file: data/avengers.mkv
# Video stream: 854 x 480
# Objects:
#
#
# FPS:0.0 	 AVG_FPS:0.0
# Objects:
#
#
# FPS:2.1 	 AVG_FPS:0.0
# Objects:
#
#
# FPS:3.9 	 AVG_FPS:0.0
# Objects:
#
# aeroplane: 54% 	(left_x:  120   top_y:  227   width:   84   height:   39)
#
# FPS:5.6 	 AVG_FPS:0.0
# Objects:
#
#
# FPS:7.2 	 AVG_FPS:0.0
# Objects:
#
# aeroplane: 29% 	(left_x:  117   top_y:  228   width:   83   height:   37)
#
# FPS:8.6 	 AVG_FPS:0.0
# Objects:
#
#
# FPS:9.8 	 AVG_FPS:0.0
# Objects:
#
#
# FPS:10.9 	 AVG_FPS:0.0
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:0.0
# Objects:
#
#
# FPS:12.9 	 AVG_FPS:0.0
# Objects:
#
#
# FPS:13.7 	 AVG_FPS:0.0
# Objects:
# ...

# %%
from IPython.display import HTML

HTML("""
    <video src="results.avi" controls="controls"> </video>
""")
# Out:
#     <video src="results.avi" controls="controls"> </video>
